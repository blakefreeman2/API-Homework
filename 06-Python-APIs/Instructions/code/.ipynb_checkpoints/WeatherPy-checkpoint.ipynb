# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import openweathermapy.core as owm
from datetime import datetime

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 632

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
City = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []


url = "http://api.openweathermap.org/data/2.5/weather?"
units='imperial'
query_url = f"{url}appid={api_key}&units={units}&q="

print(f'Beginning Data Retrieval')
print('--------------------------------')

for city in cities:
    
    try:
        response = requests.get(query_url + city).json()
        City.append(response["name"])
        Cloudiness.append(response["clouds"]["all"])
        Country.append(response["sys"]["country"])
        date = datetime.fromtimestamp(response["dt"])
        Date.append(date)
        Humidity.append(response["main"]["humidity"])
        Lat.append(response["coord"]["lat"])
        Lng.append(response["coord"]["lon"])
        Max_Temp.append(response["main"]["temp_max"])
        Wind_Speed.append(response["wind"]["speed"])
        print(f'Processing Record {cities.index(city) + 1} of set 1 | {city}')
    
    except (KeyError, IndexError):
        print('City not found. Skipping...')
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of set 1 | busselton
# Processing Record 2 of set 1 | hobart
# Processing Record 3 of set 1 | salalah
# Processing Record 4 of set 1 | punta arenas
# Processing Record 5 of set 1 | yangjiang
# City not found. Skipping...
# Processing Record 7 of set 1 | hermanus
# Processing Record 8 of set 1 | kalmunai
# Processing Record 9 of set 1 | saint-michel-des-saints
# Processing Record 10 of set 1 | kwinana
# City not found. Skipping...
# Processing Record 12 of set 1 | airai
# Processing Record 13 of set 1 | khatanga
# Processing Record 14 of set 1 | hamilton
# Processing Record 15 of set 1 | sudbury
# Processing Record 16 of set 1 | georgetown
# Processing Record 17 of set 1 | grindavik
# Processing Record 18 of set 1 | ribeira grande
# Processing Record 19 of set 1 | plettenberg bay
# Processing Record 20 of set 1 | konya
# Processing Record 21 of set 1 | jamestown
# Processing Record 22 of set 1 | binzhou
# Processing Record 23 of set 1 | novikovo
# Processing Record 24 of set 1 | rocha
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 27 of set 1 | butaritari
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 30 of set 1 | tasiilaq
# Processing Record 31 of set 1 | dikson
# Processing Record 32 of set 1 | tulun
# Processing Record 33 of set 1 | bethel
# Processing Record 34 of set 1 | fairbanks
# Processing Record 35 of set 1 | hithadhoo
# Processing Record 36 of set 1 | chuy
# Processing Record 37 of set 1 | kahului
# Processing Record 38 of set 1 | mataura
# Processing Record 39 of set 1 | bredasdorp
# Processing Record 40 of set 1 | alofi
# City not found. Skipping...
# Processing Record 42 of set 1 | necochea
# City not found. Skipping...
# Processing Record 44 of set 1 | san policarpo
# Processing Record 45 of set 1 | hammerfest
# Processing Record 46 of set 1 | mbandaka
# Processing Record 47 of set 1 | balikpapan
# Processing Record 48 of set 1 | henties bay
# Processing Record 49 of set 1 | manzil salim
# Processing Record 50 of set 1 | lagoa
# Processing Record 51 of set 1 | santa fe
# Processing Record 52 of set 1 | joao neiva
# Processing Record 53 of set 1 | rikitea
# Processing Record 54 of set 1 | avarua
# Processing Record 55 of set 1 | mersing
# Processing Record 56 of set 1 | placido de castro
# Processing Record 57 of set 1 | cape town
# Processing Record 58 of set 1 | port alfred
# Processing Record 59 of set 1 | kargasok
# Processing Record 60 of set 1 | albany
# City not found. Skipping...
# Processing Record 62 of set 1 | cabedelo
# Processing Record 63 of set 1 | gopalpur
# Processing Record 64 of set 1 | ushuaia
# Processing Record 65 of set 1 | mildura
# Processing Record 66 of set 1 | kharp
# Processing Record 67 of set 1 | kodiak
# Processing Record 68 of set 1 | puerto ayora
# Processing Record 69 of set 1 | kapaa
# City not found. Skipping...
# Processing Record 71 of set 1 | hilo
# Processing Record 72 of set 1 | kavieng
# Processing Record 73 of set 1 | dubbo
# Processing Record 74 of set 1 | santa cruz
# Processing Record 75 of set 1 | benguela
# Processing Record 76 of set 1 | qaanaaq
# Processing Record 77 of set 1 | laguna
# Processing Record 78 of set 1 | alexandria
# Processing Record 79 of set 1 | praia
# Processing Record 80 of set 1 | el tigre
# Processing Record 81 of set 1 | ochamchira
# Processing Record 82 of set 1 | kyrylivka
# Processing Record 83 of set 1 | mahebourg
# Processing Record 84 of set 1 | manhattan
# Processing Record 85 of set 1 | cayenne
# Processing Record 86 of set 1 | ostersund
# Processing Record 87 of set 1 | bluff
# Processing Record 88 of set 1 | clyde river
# Processing Record 89 of set 1 | finschhafen
# Processing Record 90 of set 1 | saint-philippe
# Processing Record 91 of set 1 | conde
# Processing Record 92 of set 1 | bambous virieux
# Processing Record 93 of set 1 | east london
# City not found. Skipping...
# Processing Record 95 of set 1 | portland
# Processing Record 96 of set 1 | yeppoon
# City not found. Skipping...
# Processing Record 98 of set 1 | yellowknife
# Processing Record 99 of set 1 | tommot
# Processing Record 100 of set 1 | koshurnikovo
# Processing Record 101 of set 1 | saskylakh
# Processing Record 102 of set 1 | nioro
# Processing Record 103 of set 1 | faya
# Processing Record 104 of set 1 | sobolevo
# Processing Record 105 of set 1 | fontem
# City not found. Skipping...
# Processing Record 107 of set 1 | port macquarie
# Processing Record 108 of set 1 | shakawe
# City not found. Skipping...
# Processing Record 110 of set 1 | havoysund
# Processing Record 111 of set 1 | castro
# City not found. Skipping...
# Processing Record 113 of set 1 | guerrero negro
# Processing Record 114 of set 1 | tokoname
# Processing Record 115 of set 1 | shenjiamen
# Processing Record 116 of set 1 | chabahar
# Processing Record 117 of set 1 | guaymas
# Processing Record 118 of set 1 | tuktoyaktuk
# Processing Record 119 of set 1 | pisco
# Processing Record 120 of set 1 | obo
# Processing Record 121 of set 1 | kaeo
# City not found. Skipping...
# Processing Record 123 of set 1 | yining
# City not found. Skipping...
# Processing Record 125 of set 1 | leshukonskoye
# Processing Record 126 of set 1 | gornopravdinsk
# Processing Record 127 of set 1 | winnemucca
# Processing Record 128 of set 1 | barrow
# Processing Record 129 of set 1 | vaini
# City not found. Skipping...
# Processing Record 131 of set 1 | carnarvon
# Processing Record 132 of set 1 | ilo
# Processing Record 133 of set 1 | new norfolk
# Processing Record 134 of set 1 | kununurra
# Processing Record 135 of set 1 | constitucion
# Processing Record 136 of set 1 | stanislav
# Processing Record 137 of set 1 | arraial do cabo
# Processing Record 138 of set 1 | fortuna
# Processing Record 139 of set 1 | altay
# Processing Record 140 of set 1 | bayburt
# Processing Record 141 of set 1 | nome
# Processing Record 142 of set 1 | sri aman
# City not found. Skipping...
# Processing Record 144 of set 1 | trelew
# Processing Record 145 of set 1 | codrington
# Processing Record 146 of set 1 | torbay
# Processing Record 147 of set 1 | baykit
# Processing Record 148 of set 1 | khandyga
# Processing Record 149 of set 1 | saint-francois
# Processing Record 150 of set 1 | manoel urbano
# Processing Record 151 of set 1 | uribia
# Processing Record 152 of set 1 | marawi
# Processing Record 153 of set 1 | nikolskoye
# Processing Record 154 of set 1 | forio
# Processing Record 155 of set 1 | taft
# Processing Record 156 of set 1 | banda aceh
# Processing Record 157 of set 1 | cabo san lucas
# Processing Record 158 of set 1 | jalu
# Processing Record 159 of set 1 | ishigaki
# Processing Record 160 of set 1 | severo-kurilsk
# Processing Record 161 of set 1 | san andres
# City not found. Skipping...
# Processing Record 163 of set 1 | cidreira
# Processing Record 164 of set 1 | nemuro
# Processing Record 165 of set 1 | mar del plata
# Processing Record 166 of set 1 | dowa
# Processing Record 167 of set 1 | etchojoa
# Processing Record 168 of set 1 | pevek
# Processing Record 169 of set 1 | bani walid
# Processing Record 170 of set 1 | aksarka
# Processing Record 171 of set 1 | gladstone
# Processing Record 172 of set 1 | belmonte
# Processing Record 173 of set 1 | selikhino
# Processing Record 174 of set 1 | vila velha
# Processing Record 175 of set 1 | homer
# Processing Record 176 of set 1 | kandrian
# Processing Record 177 of set 1 | lanigan
# Processing Record 178 of set 1 | upernavik
# Processing Record 179 of set 1 | colesberg
# Processing Record 180 of set 1 | hambantota
# Processing Record 181 of set 1 | talnakh
# Processing Record 182 of set 1 | lagos
# Processing Record 183 of set 1 | thai binh
# Processing Record 184 of set 1 | czluchow
# City not found. Skipping...
# Processing Record 186 of set 1 | kutoarjo
# Processing Record 187 of set 1 | evensk
# Processing Record 188 of set 1 | longyearbyen
# Processing Record 189 of set 1 | arlit
# Processing Record 190 of set 1 | byron bay
# Processing Record 191 of set 1 | victoria
# Processing Record 192 of set 1 | sayat
# Processing Record 193 of set 1 | mocuba
# Processing Record 194 of set 1 | cherskiy
# Processing Record 195 of set 1 | mujiayingzi
# Processing Record 196 of set 1 | arman
# Processing Record 197 of set 1 | bubaque
# Processing Record 198 of set 1 | yulara
# Processing Record 199 of set 1 | brigantine
# Processing Record 200 of set 1 | wajima
# Processing Record 201 of set 1 | sahuaripa
# Processing Record 202 of set 1 | fare
# Processing Record 203 of set 1 | ponta do sol
# Processing Record 204 of set 1 | itacoatiara
# City not found. Skipping...
# Processing Record 206 of set 1 | vardo
# Processing Record 207 of set 1 | borogontsy
# Processing Record 208 of set 1 | pemba
# Processing Record 209 of set 1 | bandarbeyla
# Processing Record 210 of set 1 | atuona
# Processing Record 211 of set 1 | romitan
# Processing Record 212 of set 1 | bay roberts
# Processing Record 213 of set 1 | shache
# Processing Record 214 of set 1 | mbini
# Processing Record 215 of set 1 | ustka
# Processing Record 216 of set 1 | wagar
# Processing Record 217 of set 1 | hit
# Processing Record 218 of set 1 | mana
# Processing Record 219 of set 1 | isangel
# Processing Record 220 of set 1 | trairi
# Processing Record 221 of set 1 | shetpe
# Processing Record 222 of set 1 | iqaluit
# Processing Record 223 of set 1 | kirovsk
# Processing Record 224 of set 1 | berlevag
# City not found. Skipping...
# Processing Record 226 of set 1 | coquimbo
# Processing Record 227 of set 1 | burgeo
# Processing Record 228 of set 1 | paamiut
# Processing Record 229 of set 1 | souillac
# Processing Record 230 of set 1 | oranjemund
# Processing Record 231 of set 1 | saldanha
# Processing Record 232 of set 1 | aksu
# Processing Record 233 of set 1 | kotma
# Processing Record 234 of set 1 | viedma
# Processing Record 235 of set 1 | petrov val
# Processing Record 236 of set 1 | puerto narino
# Processing Record 237 of set 1 | lebu
# Processing Record 238 of set 1 | manaus
# Processing Record 239 of set 1 | nantucket
# Processing Record 240 of set 1 | nouadhibou
# Processing Record 241 of set 1 | pochutla
# Processing Record 242 of set 1 | norman wells
# Processing Record 243 of set 1 | labuhan
# Processing Record 244 of set 1 | tiksi
# Processing Record 245 of set 1 | hoogeveen
# Processing Record 246 of set 1 | savyntsi
# Processing Record 247 of set 1 | chapaevsk
# Processing Record 248 of set 1 | acapulco
# Processing Record 249 of set 1 | camopi
# Processing Record 250 of set 1 | luderitz
# Processing Record 251 of set 1 | tilichiki
# Processing Record 252 of set 1 | katsuura
# City not found. Skipping...
# Processing Record 254 of set 1 | develi
# Processing Record 255 of set 1 | pervomayskoye
# Processing Record 256 of set 1 | preston
# Processing Record 257 of set 1 | thompson
# Processing Record 258 of set 1 | praya
# Processing Record 259 of set 1 | roblin
# Processing Record 260 of set 1 | marienburg
# Processing Record 261 of set 1 | vanavara
# Processing Record 262 of set 1 | acajutla
# Processing Record 263 of set 1 | nishihara
# Processing Record 264 of set 1 | tabuk
# Processing Record 265 of set 1 | leh
# Processing Record 266 of set 1 | hualmay
# Processing Record 267 of set 1 | esperance
# Processing Record 268 of set 1 | araouane
# Processing Record 269 of set 1 | ormara
# Processing Record 270 of set 1 | saint george
# Processing Record 271 of set 1 | hare bay
# Processing Record 272 of set 1 | amga
# Processing Record 273 of set 1 | klaksvik
# Processing Record 274 of set 1 | aurora
# Processing Record 275 of set 1 | ola
# Processing Record 276 of set 1 | provideniya
# Processing Record 277 of set 1 | sioux lookout
# Processing Record 278 of set 1 | ladispoli
# Processing Record 279 of set 1 | papara
# Processing Record 280 of set 1 | touros
# City not found. Skipping...
# Processing Record 282 of set 1 | genoa
# Processing Record 283 of set 1 | vikhorevka
# Processing Record 284 of set 1 | baillif
# Processing Record 285 of set 1 | putina
# Processing Record 286 of set 1 | belen
# Processing Record 287 of set 1 | dalbandin
# Processing Record 288 of set 1 | albanel
# City not found. Skipping...
# Processing Record 290 of set 1 | saint-augustin
# Processing Record 291 of set 1 | castanos
# Processing Record 292 of set 1 | ranfurly
# Processing Record 293 of set 1 | garden city
# Processing Record 294 of set 1 | halifax
# Processing Record 295 of set 1 | sheboygan
# Processing Record 296 of set 1 | puerto colombia
# Processing Record 297 of set 1 | bereda
# Processing Record 298 of set 1 | omboue
# Processing Record 299 of set 1 | turinsk
# Processing Record 300 of set 1 | kuruman
# Processing Record 301 of set 1 | san quintin
# Processing Record 302 of set 1 | mikuni
# Processing Record 303 of set 1 | guanica
# Processing Record 304 of set 1 | parabel
# City not found. Skipping...
# Processing Record 306 of set 1 | lompoc
# Processing Record 307 of set 1 | haines junction
# Processing Record 308 of set 1 | geraldton
# Processing Record 309 of set 1 | vanimo
# City not found. Skipping...
# Processing Record 311 of set 1 | cloquet
# Processing Record 312 of set 1 | bloemfontein
# Processing Record 313 of set 1 | sao joao da barra
# Processing Record 314 of set 1 | kirovskiy
# Processing Record 315 of set 1 | moree
# Processing Record 316 of set 1 | plaster rock
# Processing Record 317 of set 1 | springfield
# Processing Record 318 of set 1 | kintampo
# Processing Record 319 of set 1 | yar-sale
# Processing Record 320 of set 1 | severo-yeniseyskiy
# Processing Record 321 of set 1 | oktyabrskiy
# Processing Record 322 of set 1 | sinnamary
# Processing Record 323 of set 1 | faanui
# Processing Record 324 of set 1 | tabas
# Processing Record 325 of set 1 | ilulissat
# Processing Record 326 of set 1 | san patricio
# Processing Record 327 of set 1 | kysyl-syr
# Processing Record 328 of set 1 | bernalillo
# Processing Record 329 of set 1 | santa lucia
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 332 of set 1 | manono
# City not found. Skipping...
# Processing Record 334 of set 1 | port blair
# Processing Record 335 of set 1 | kruisfontein
# Processing Record 336 of set 1 | neiafu
# Processing Record 337 of set 1 | waingapu
# Processing Record 338 of set 1 | broken hill
# Processing Record 339 of set 1 | zhanaozen
# City not found. Skipping...
# Processing Record 341 of set 1 | lorengau
# Processing Record 342 of set 1 | cockburn town
# City not found. Skipping...
# Processing Record 344 of set 1 | ratnagiri
# Processing Record 345 of set 1 | marathon
# City not found. Skipping...
# Processing Record 347 of set 1 | sorland
# Processing Record 348 of set 1 | anzhero-sudzhensk
# Processing Record 349 of set 1 | tacna
# Processing Record 350 of set 1 | praia da vitoria
# Processing Record 351 of set 1 | beloha
# Processing Record 352 of set 1 | arvi
# Processing Record 353 of set 1 | uvalde
# Processing Record 354 of set 1 | dunda
# Processing Record 355 of set 1 | gairo
# Processing Record 356 of set 1 | canutama
# Processing Record 357 of set 1 | corrales
# Processing Record 358 of set 1 | ancud
# Processing Record 359 of set 1 | xiazhen
# Processing Record 360 of set 1 | westport
# Processing Record 361 of set 1 | belyy yar
# City not found. Skipping...
# Processing Record 363 of set 1 | biggar
# Processing Record 364 of set 1 | tongchuan
# Processing Record 365 of set 1 | ulaanbaatar
# Processing Record 366 of set 1 | saint anthony
# Processing Record 367 of set 1 | dingle
# Processing Record 368 of set 1 | ossora
# Processing Record 369 of set 1 | simpang
# Processing Record 370 of set 1 | sibolga
# Processing Record 371 of set 1 | huarmey
# Processing Record 372 of set 1 | teguldet
# Processing Record 373 of set 1 | nikki
# Processing Record 374 of set 1 | karaton
# Processing Record 375 of set 1 | sola
# Processing Record 376 of set 1 | hasaki
# Processing Record 377 of set 1 | narsaq
# Processing Record 378 of set 1 | phrae
# Processing Record 379 of set 1 | gizo
# Processing Record 380 of set 1 | ghatanji
# Processing Record 381 of set 1 | tuensang
# Processing Record 382 of set 1 | alta floresta
# Processing Record 383 of set 1 | tuatapere
# Processing Record 384 of set 1 | buchanan
# Processing Record 385 of set 1 | guaranda
# Processing Record 386 of set 1 | dwarka
# Processing Record 387 of set 1 | bayaguana
# Processing Record 388 of set 1 | qaqortoq
# Processing Record 389 of set 1 | lavrentiya
# Processing Record 390 of set 1 | nara
# Processing Record 391 of set 1 | katete
# Processing Record 392 of set 1 | broome
# City not found. Skipping...
# Processing Record 394 of set 1 | tazovskiy
# Processing Record 395 of set 1 | balkanabat
# Processing Record 396 of set 1 | port hardy
# Processing Record 397 of set 1 | sakaiminato
# Processing Record 398 of set 1 | mehamn
# Processing Record 399 of set 1 | palmer
# City not found. Skipping...
# Processing Record 401 of set 1 | kaitangata
# Processing Record 402 of set 1 | mayumba
# Processing Record 403 of set 1 | bardsir
# Processing Record 404 of set 1 | karaman
# Processing Record 405 of set 1 | rudnogorsk
# Processing Record 406 of set 1 | kapit
# Processing Record 407 of set 1 | mareeba
# City not found. Skipping...
# Processing Record 409 of set 1 | sao filipe
# Processing Record 410 of set 1 | dekar
# Processing Record 411 of set 1 | saint-georges
# Processing Record 412 of set 1 | esmeraldas
# Processing Record 413 of set 1 | tangwani
# Processing Record 414 of set 1 | hatillo
# Processing Record 415 of set 1 | muisne
# Processing Record 416 of set 1 | diffa
# City not found. Skipping...
# Processing Record 418 of set 1 | arkhangelsk
# Processing Record 419 of set 1 | zwedru
# Processing Record 420 of set 1 | hauterive
# Processing Record 421 of set 1 | taltal
# Processing Record 422 of set 1 | fort-shevchenko
# Processing Record 423 of set 1 | miandrivazo
# Processing Record 424 of set 1 | margate
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 427 of set 1 | bilma
# Processing Record 428 of set 1 | guantanamo
# Processing Record 429 of set 1 | tura
# Processing Record 430 of set 1 | montepuez
# Processing Record 431 of set 1 | dhidhdhoo
# City not found. Skipping...
# Processing Record 433 of set 1 | walvis bay
# Processing Record 434 of set 1 | port lincoln
# Processing Record 435 of set 1 | deputatskiy
# Processing Record 436 of set 1 | piacabucu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 439 of set 1 | port elizabeth
# Processing Record 440 of set 1 | petaluma
# Processing Record 441 of set 1 | turukhansk
# Processing Record 442 of set 1 | ostrovnoy
# Processing Record 443 of set 1 | ust-nera
# City not found. Skipping...
# Processing Record 445 of set 1 | svarstad
# Processing Record 446 of set 1 | thatta
# Processing Record 447 of set 1 | folldal
# Processing Record 448 of set 1 | searcy
# Processing Record 449 of set 1 | kavaratti
# City not found. Skipping...
# Processing Record 451 of set 1 | tarko-sale
# Processing Record 452 of set 1 | lamar
# Processing Record 453 of set 1 | inirida
# Processing Record 454 of set 1 | kurchum
# Processing Record 455 of set 1 | kastamonu
# Processing Record 456 of set 1 | chokurdakh
# Processing Record 457 of set 1 | jishu
# Processing Record 458 of set 1 | kroya
# City not found. Skipping...
# Processing Record 460 of set 1 | hargeysa
# Processing Record 461 of set 1 | patuli
# Processing Record 462 of set 1 | chitrakonda
# Processing Record 463 of set 1 | niono
# Processing Record 464 of set 1 | buin
# Processing Record 465 of set 1 | leningradskiy
# Processing Record 466 of set 1 | marsh harbour
# Processing Record 467 of set 1 | rehoboth
# Processing Record 468 of set 1 | gravdal
# Processing Record 469 of set 1 | kondinskoye
# Processing Record 470 of set 1 | meulaboh
# Processing Record 471 of set 1 | moerai
# Processing Record 472 of set 1 | stony mountain
# Processing Record 473 of set 1 | ascoli piceno
# Processing Record 474 of set 1 | pemberton
# City not found. Skipping...
# Processing Record 476 of set 1 | akot
# Processing Record 477 of set 1 | takoradi
# Processing Record 478 of set 1 | sangmelima
# Processing Record 479 of set 1 | nizwa
# Processing Record 480 of set 1 | soltsy
# Processing Record 481 of set 1 | abagur
# Processing Record 482 of set 1 | batemans bay
# Processing Record 483 of set 1 | jiaocheng
# Processing Record 484 of set 1 | ballina
# Processing Record 485 of set 1 | krasnokamensk
# Processing Record 486 of set 1 | te anau
# Processing Record 487 of set 1 | sanchazi
# Processing Record 488 of set 1 | srivardhan
# Processing Record 489 of set 1 | namibe
# Processing Record 490 of set 1 | villa carlos paz
# Processing Record 491 of set 1 | perry
# Processing Record 492 of set 1 | ketchikan
# Processing Record 493 of set 1 | wewak
# City not found. Skipping...
# Processing Record 495 of set 1 | muros
# Processing Record 496 of set 1 | udachnyy
# Processing Record 497 of set 1 | huoqiu
# Processing Record 498 of set 1 | camalu
# City not found. Skipping...
# Processing Record 500 of set 1 | dunedin
# Processing Record 501 of set 1 | tarakan
# Processing Record 502 of set 1 | komsomolskiy
# Processing Record 503 of set 1 | lazaro cardenas
# Processing Record 504 of set 1 | abrau-dyurso
# Processing Record 505 of set 1 | bambanglipuro
# Processing Record 506 of set 1 | husavik
# Processing Record 507 of set 1 | mehran
# Processing Record 508 of set 1 | ilhabela
# City not found. Skipping...
# Processing Record 510 of set 1 | katsina
# Processing Record 511 of set 1 | tapes
# Processing Record 512 of set 1 | enumclaw
# City not found. Skipping...
# Processing Record 514 of set 1 | mirabad
# Processing Record 515 of set 1 | beidao
# Processing Record 516 of set 1 | vredendal
# Processing Record 517 of set 1 | porbandar
# Processing Record 518 of set 1 | ekhabi
# Processing Record 519 of set 1 | sisimiut
# Processing Record 520 of set 1 | melfi
# Processing Record 521 of set 1 | dustlik
# Processing Record 522 of set 1 | hanmer springs
# Processing Record 523 of set 1 | rawson
# Processing Record 524 of set 1 | troitsko-pechorsk
# Processing Record 525 of set 1 | ulaangom
# Processing Record 526 of set 1 | xiongyue
# Processing Record 527 of set 1 | celestun
# Processing Record 528 of set 1 | helena
# Processing Record 529 of set 1 | san cristobal
# Processing Record 530 of set 1 | findhorn
# Processing Record 531 of set 1 | bathsheba
# Processing Record 532 of set 1 | ifakara
# City not found. Skipping...
# Processing Record 534 of set 1 | nkoteng
# Processing Record 535 of set 1 | opole lubelskie
# Processing Record 536 of set 1 | port hedland
# Processing Record 537 of set 1 | kalaleh
# Processing Record 538 of set 1 | banting
# Processing Record 539 of set 1 | wilkie
# Processing Record 540 of set 1 | rio de janeiro
# Processing Record 541 of set 1 | kuito
# City not found. Skipping...
# Processing Record 543 of set 1 | poronaysk
# Processing Record 544 of set 1 | comodoro rivadavia
# Processing Record 545 of set 1 | ixtapa
# Processing Record 546 of set 1 | wilson
# City not found. Skipping...
# Processing Record 548 of set 1 | normandin
# Processing Record 549 of set 1 | dangriga
# City not found. Skipping...
# Processing Record 551 of set 1 | tolaga bay
# Processing Record 552 of set 1 | teahupoo
# Processing Record 553 of set 1 | pastavy
# Processing Record 554 of set 1 | itaituba
# Processing Record 555 of set 1 | haverfordwest
# Processing Record 556 of set 1 | buckeye
# Processing Record 557 of set 1 | cedar city
# Processing Record 558 of set 1 | tahe
# Processing Record 559 of set 1 | coihaique
# Processing Record 560 of set 1 | aykhal
# City not found. Skipping...
# Processing Record 562 of set 1 | sokoni
# Processing Record 563 of set 1 | beringovskiy
# Processing Record 564 of set 1 | sao sebastiao
# Processing Record 565 of set 1 | semporna
# Processing Record 566 of set 1 | bridlington
# Processing Record 567 of set 1 | palana
# Processing Record 568 of set 1 | lady frere
# Processing Record 569 of set 1 | waipawa
# Processing Record 570 of set 1 | sijunjung
# Processing Record 571 of set 1 | pandan
# Processing Record 572 of set 1 | christchurch
# Processing Record 573 of set 1 | cabra
# Processing Record 574 of set 1 | perth
# Processing Record 575 of set 1 | wajid
# Processing Record 576 of set 1 | warmbad
# Processing Record 577 of set 1 | kirakira
# Processing Record 578 of set 1 | los llanos de aridane
# Processing Record 579 of set 1 | lidkoping
# Processing Record 580 of set 1 | beaucaire
# Processing Record 581 of set 1 | sabratah
# Processing Record 582 of set 1 | jenison
# Processing Record 583 of set 1 | nosy varika
# Processing Record 584 of set 1 | fort wellington
# Processing Record 585 of set 1 | yabelo
# Processing Record 586 of set 1 | quesnel
# Processing Record 587 of set 1 | omachi
# Processing Record 588 of set 1 | bourail
# Processing Record 589 of set 1 | chumikan
# Processing Record 590 of set 1 | katherine
# Processing Record 591 of set 1 | dongning
# Processing Record 592 of set 1 | palmeira das missoes
# Processing Record 593 of set 1 | santa maria
# Processing Record 594 of set 1 | caravelas
# Processing Record 595 of set 1 | inzer
# Processing Record 596 of set 1 | rapid valley
# Processing Record 597 of set 1 | jatai
# Processing Record 598 of set 1 | dauphin
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 601 of set 1 | maraa
# Processing Record 602 of set 1 | teknaf
# Processing Record 603 of set 1 | mabaruma
# Processing Record 604 of set 1 | kozhevnikovo
# Processing Record 605 of set 1 | emilio carranza
# Processing Record 606 of set 1 | hami
# Processing Record 607 of set 1 | road town
# Processing Record 608 of set 1 | buala
# Processing Record 609 of set 1 | yerbogachen
# Processing Record 610 of set 1 | taksimo
# Processing Record 611 of set 1 | mecca
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 614 of set 1 | shelburne
# Processing Record 615 of set 1 | gayny
# Processing Record 616 of set 1 | ghanzi
# Processing Record 617 of set 1 | zyryanka
# Processing Record 618 of set 1 | srednekolymsk
# Processing Record 619 of set 1 | luanda
# City not found. Skipping...
# Processing Record 621 of set 1 | tapah
# Processing Record 622 of set 1 | jacqueville
# Processing Record 623 of set 1 | bilibino
# Processing Record 624 of set 1 | log
# Processing Record 625 of set 1 | shibetsu
# Processing Record 626 of set 1 | roald
# Processing Record 627 of set 1 | amuntai
# Processing Record 628 of set 1 | bom jardim
# Processing Record 629 of set 1 | moosomin
# Processing Record 630 of set 1 | tiarei
# Processing Record 631 of set 1 | nanortalik
# Processing Record 632 of set 1 | angoche

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
WeatherPy_df = pd.DataFrame(
    {'City': City,
     'Cloudiness': Cloudiness,
     'Country': Country,
     'Timestamp': Date,
     'Humidity': Humidity,
     'Longitude': Lng,
     'Latitude': Lat,
     'Max_Temperature': Max_Temp,
     'Wind_Speed': Wind_Speed
    })
WeatherPy_df.count()
# Out:
# City               570
# Cloudiness         570
# Country            570
# Timestamp          570
# Humidity           570
# Longitude          570
# Latitude           570
# Max_Temperature    570
# Wind_Speed         570
# dtype: int64

# %%
WeatherPy_df.head()
# Out:
#            City  Cloudiness Country           Timestamp  Humidity  Longitude  \
# 0     Busselton         100      AU 2019-07-20 15:51:44        54     115.35
# 1        Hobart          40      AU 2019-07-20 15:51:14        62     147.33
# 2       Salalah          75      OM 2019-07-20 15:51:44        88      54.10
# 3  Punta Arenas          75      CL 2019-07-20 15:51:45        69     -70.91
# 4     Yangjiang          85      CN 2019-07-20 15:51:45        66     111.96
#
#    Latitude  Max_Temperature  Wind_Speed
# 0    -33.64            59.00       27.63
# 1    -42.88            51.80       12.75
# 2     17.01            80.60        1.12
# 3    -53.16            37.40       13.87
# 4     21.85            87.01        1.52

# %%
WeatherPy_df.to_csv('WeatherPy.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
WeatherPy_Lat_axis = WeatherPy_df['Latitude']
Max_Temperature_axis = WeatherPy_df['Max_Temperature']
Humidity_axis = WeatherPy_df['Humidity']
Cloudiness_axis = WeatherPy_df['Cloudiness']
Wind_Speed_axis = WeatherPy_df['Wind_Speed']

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(WeatherPy_Lat_axis, Max_Temperature_axis, marker="o", facecolors="green", edgecolors="black",alpha=0.75)
plt.grid()
plt.title("City Latitude vs. Termperature"+" "+str(WeatherPy_df['Timestamp'][1]))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.savefig("City Latitude vs. Termperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(WeatherPy_Lat_axis, Humidity_axis, marker="o", facecolors="green", edgecolors="black",alpha=0.75)
plt.grid()
plt.title("City Latitude vs. Humidity"+" "+str(WeatherPy_df['Timestamp'][1]))
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.savefig("City Latitude vs. Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(WeatherPy_Lat_axis, Cloudiness_axis, marker="o", facecolors="green", edgecolors="black",alpha=0.75)
plt.grid()
plt.title("City Latitude vs. Cloudiness"+" "+str(WeatherPy_df['Timestamp'][1]))
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")

plt.savefig("City Latitude vs. Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(WeatherPy_Lat_axis, Wind_Speed_axis, marker="o", facecolors="green", edgecolors="black",alpha=0.75)
plt.grid()
plt.title("City Latitude vs. Wind Speed"+" "+str(WeatherPy_df['Timestamp'][1]))
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.savefig("City Latitude vs. Wind Speed.png")
